# %%
import pandas as pd

pedidos_df = pd.read_excel(r"C:\Users\Pichau\Desktop\Projeto-Estoque\Pedidos.xlsx")

# %%
produtos = []
quantidade = []
valor_un = []
for i_produto in range(len(pedidos_df)):
    produtos.extend(pedidos_df['Produtos'][i_produto].split(','))
    quantidade.extend(pedidos_df['Quantidade'][i_produto].split(','))
    valor_un.extend(pedidos_df['Valor un'][i_produto].split(','))

# %%
i_vendas
# Out:
# 2

# %%
num_vendas = []
data_hora = []
cliente = []
bairro = []
for i_vendas in range(len(pedidos_df)):
    for i in range(int(len(produtos)/2)):
        num_vendas.append(pedidos_df['Número da venda'][i_vendas])
        data_hora.append(pedidos_df['Data/hora de emissão'][i_vendas])
        cliente.append(pedidos_df['Cliente'][i_vendas])
        bairro.append(pedidos_df['Bairro'][i_vendas])

# %%
data = {
    "Número da venda": num_vendas,
    "Data e Hora": data_hora,
    "Cliente": cliente,
    "Bairro": bairro,
    "Produtos": produtos,
    "Quantidade": quantidade,
    "Valor Un": valor_un,
}

# %%
output = pd.DataFrame.from_dict(data)
output
# Out:
#     Número da venda          Data e Hora Cliente          Bairro  \
# 0              5605  30/06/2022 00:00:00   BRUNO      Bela Vista
# 1              5605  30/06/2022 00:00:00   BRUNO      Bela Vista
# 2              5605  30/06/2022 00:00:00   BRUNO      Bela Vista
# 3              5605  30/06/2022 00:00:00   BRUNO      Bela Vista
# 4              5605  30/06/2022 00:00:00   BRUNO      Bela Vista
# 5              5605  30/06/2022 00:00:00   BRUNO      Bela Vista
# 6              5605  30/06/2022 00:00:00   BRUNO      Bela Vista
# 7              5605  30/06/2022 00:00:00   BRUNO      Bela Vista
# 8              5606  30/06/2022 00:00:01  CLEBER    Vila Andrade
# 9              5606  30/06/2022 00:00:01  CLEBER    Vila Andrade
# 10             5606  30/06/2022 00:00:01  CLEBER    Vila Andrade
# 11             5606  30/06/2022 00:00:01  CLEBER    Vila Andrade
# 12             5606  30/06/2022 00:00:01  CLEBER    Vila Andrade
# 13             5606  30/06/2022 00:00:01  CLEBER    Vila Andrade
# 14             5606  30/06/2022 00:00:01  CLEBER    Vila Andrade
# 15             5606  30/06/2022 00:00:01  CLEBER    Vila Andrade
# 16             5607  2022-06-30 00:00:02  AFONSO  Parque Arariba
# 17             5607  2022-06-30 00:00:02  AFONSO  Parque Arariba
# 18             5607  2022-06-30 00:00:02  AFONSO  Parque Arariba
# 19             5607  2022-06-30 00:00:02  AFONSO  Parque Arariba
# 20             5607  2022-06-30 00:00:02  AFONSO  Parque Arariba
# 21             5607  2022-06-30 00:00:02  AFONSO  Parque Arariba
# 22             5607  2022-06-30 00:00:02  AFONSO  Parque Arariba
# 23             5607  2022-06-30 00:00:02  AFONSO  Parque Arariba
#
#                                              Produtos Quantidade Valor Un
# 0   001 MESA DE PING PONG OFICIAL DOBRAVEL 15MM MD...          1     1829
# 1               ABACO ABERTO DE PINOS EM MADEIRA C/56          1       66
# 2    BEBEDOURO E PURIFIC ÁGUA RESIST. 100 LITROS -...          1     4160
# 3                  LAPIS JUMBO MAD. C/ APONT. CX C/12          1   178.95
# 4               PAPEL VERGE 120G BRANCO A4 PT. C/ 50F          1       26
# 5                                  ALCOOL LIQ. 70° 5L          1       72
# 6                ALCOOL EM GEL 70% 430G C/ TAMPA PUMP          1     15.8
# 7                         ALCOOL EM GEL 70% GL. C/ 5L          1       72
# 8   001 MESA DE PING PONG OFICIAL DOBRAVEL 15MM MD...          2     1829
# 9               ABACO ABERTO DE PINOS EM MADEIRA C/56          2       66
# 10   BEBEDOURO E PURIFIC ÁGUA RESIST. 100 LITROS -...          2     4160
# 11                 LAPIS JUMBO MAD. C/ APONT. CX C/12          2   178.95
# 12              PAPEL VERGE 120G BRANCO A4 PT. C/ 50F          2       26
# 13                                 ALCOOL LIQ. 70° 5L          2       72
# 14               ALCOOL EM GEL 70% 430G C/ TAMPA PUMP          2     15.8
# 15                        ALCOOL EM GEL 70% GL. C/ 5L          2       72
# 16  001 MESA DE PING PONG OFICIAL DOBRAVEL 15MM MD...          3     1829
# 17              ABACO ABERTO DE PINOS EM MADEIRA C/56          3       66
# 18   BEBEDOURO E PURIFIC ÁGUA RESIST. 100 LITROS -...          3     4160
# 19                 LAPIS JUMBO MAD. C/ APONT. CX C/12          3   178.95
# 20              PAPEL VERGE 120G BRANCO A4 PT. C/ 50F          3       26
# 21                                 ALCOOL LIQ. 70° 5L          3       72
# 22               ALCOOL EM GEL 70% 430G C/ TAMPA PUMP          3     15.8
# 23                        ALCOOL EM GEL 70% GL. C/ 5L          3       72

# %%
output.to_excel(r"C:\Users\Pichau\Desktop\Projeto-Estoque\output-arquivos\output1.xlsx", index=False)
